# %%
import pandas as pd

# %%
data_2018 = pd.read_csv("2018.csv") 
data_2017 = pd.read_csv("2017.csv") 
data_2016 = pd.read_csv("2016.csv")

# %%
columns_2018=data_2018.columns
columns_2017=data_2017.columns
columns_2016=data_2016.columns

# %%
columns_2018==columns_2017
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True])

# %%
columns_2018==columns_2016
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True])

# %%
columns_2018
# Out:
# Index(['FL_DATE', 'OP_CARRIER', 'OP_CARRIER_FL_NUM', 'ORIGIN', 'DEST',
#        'CRS_DEP_TIME', 'DEP_TIME', 'DEP_DELAY', 'TAXI_OUT', 'WHEELS_OFF',
#        'WHEELS_ON', 'TAXI_IN', 'CRS_ARR_TIME', 'ARR_TIME', 'ARR_DELAY',
#        'CANCELLED', 'CANCELLATION_CODE', 'DIVERTED', 'CRS_ELAPSED_TIME',
#        'ACTUAL_ELAPSED_TIME', 'AIR_TIME', 'DISTANCE', 'CARRIER_DELAY',
#        'WEATHER_DELAY', 'NAS_DELAY', 'SECURITY_DELAY', 'LATE_AIRCRAFT_DELAY',
#        'Unnamed: 27'],
#       dtype='object')

# %%
data_2016.count()[0]
data_2017.count()[0]
data_2018.count()[0]
# Out:
# 7213446

# %%
file_2018_path = r"C:\Users\anne_\OneDrive\Documents\GitHub\Final-Project\Resources\2018.csv"

# %%
data_2018_df = pd.read_csv(file_2018_path,encoding="utf-8")
data_2018_df.head(10)
# Out:
#       FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0  2018-01-01         UA               2429    EWR  DEN          1517
# 1  2018-01-01         UA               2427    LAS  SFO          1115
# 2  2018-01-01         UA               2426    SNA  DEN          1335
# 3  2018-01-01         UA               2425    RSW  ORD          1546
# 4  2018-01-01         UA               2424    ORD  ALB           630
# 5  2018-01-01         UA               2422    ORD  OMA          2241
# 6  2018-01-01         UA               2421    IAH  LAS           750
# 7  2018-01-01         UA               2420    DEN  CID          1324
# 8  2018-01-01         UA               2419    SMF  EWR          2224
# 9  2018-01-01         UA               2418    RIC  DEN          1601
#
#    DEP_TIME  DEP_DELAY  TAXI_OUT  WHEELS_OFF  ...  CRS_ELAPSED_TIME  \
# 0    1512.0       -5.0      15.0      1527.0  ...             268.0
# ...

# %%
data_2018_df.loc[data_2018_df['ORIGIN'] == "PHX"]
# Out:
#             FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 81       2018-01-01         UA               2135    PHX  DEN          1435
# 134      2018-01-01         UA               2083    PHX  IAH           730
# 207      2018-01-01         UA               2000    PHX  ORD          1340
# 235      2018-01-01         UA               1976    PHX  EWR          2330
# 415      2018-01-01         UA               1774    PHX  DEN           600
# ...             ...        ...                ...    ...  ...           ...
# 7213333  2018-12-31         AA               1702    PHX  LAX           937
# 7213369  2018-12-31         AA               1743    PHX  DEN          1330
# 7213382  2018-12-31         AA               1760    PHX  AUS          1328
# 7213413  2018-12-31         AA               1792    PHX  CMH           955
# 7213437  2018-12-31         AA               1812    PHX  PDX           825
#
# ...

# %%
# Remove unecessary columns from the DataFrame and save the new DataFrame
# Only keep: "isbn", "original_publication_year", "original_title", "authors",
# "ratings_1", "ratings_2", "ratings_3", "ratings_4", "ratings_5"
reduced_2018_df = data_2018[['WHEELS_OFF', 'WHEELS_ON', 'CRS_ELAPSED_TIME',
      'AIR_TIME', 'DISTANCE']]
reduced_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-6108a9376aac> in <module>
#       4 reduced_2018_df = data_2018[['WHEELS_OFF', 'WHEELS_ON', 'CRS_ELAPSED_TIME',
#       5       'AIR_TIME', 'DISTANCE']]
# ----> 6 reduced_df.head()
#
# NameError: name 'reduced_df' is not defined
